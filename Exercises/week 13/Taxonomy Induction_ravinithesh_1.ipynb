# %% [markdown]
# # Exercise: Taxonomy Induction
#
# <br>
# In this exercise, we will perform the various steps commonly employed for unsupervised taxonomy induction from text corpora. Taxonomy induction from text typically consists of three main steps:
#
# <ol>
#   <li><b>Relations Extraction:</b> In this step, we use lexico-syntactic patterns to extract <b>IsA</b> relations from text. An example of IsA relation is (<i>apple, fruit</i>), which implies that <i>apple</i> is a type of fruit.</li>
#   <br>
#   <li><b>Initial Graph Construction:</b> In this step, we aggregate the extracted IsA relations to construct a potentially-noisy initial hypernym graph.</li>
#   <br>
#   <li><b>Graph Pruning:</b> In the final step, we perform some pruning or optimization steps to induce the a final clean taxonomy.</li>
# </ol>
#
# <br>
# We will describe these steps in detail in the rest of this exercise.
#
#
# ## Question 1 - Relations Extraction
#
#
# In this part of the exercise, we will run a small-scale extraction of IsA relations and inspect the results. Relations extraction uses lexico-syntactic patterns to identify IsA relations from unstructured text. Examples of lexico-syntactic patterns include:
#
#  Lexico-syntactic pattern | Sample matching text
#   ------|------------------
#   <b>X</b> is a <b>Y</b>     | <i><b>apple</b> is a <b>fruit</b></i>, <i><b>switzerland</b> is a <b>country</b></i>
#   <b>X</b> such as <b>Y</b>     | <i><b>fruits</b> such as <b>mango</b></i>, <i><b>scientists</b> such as <b>Einstein</b></i>
#   <b>X</b> is an example of <b>Y</b>     | <i><b>iphone</b> is an example of <b>smartphone</b></i>
#
#   <br>
#   In this exercise, we will use such lexico-syntactic patterns to identify IsA relations from text.
#
#
#   ###  Question 1.a
#
#   Load the given file <b>wiki_food_en.txt</b> into memory using the following code:

# %%
def load_text_file(filename):
    file_text = []
    with open(filename, encoding="utf-8") as fp:
        for line in fp:
            file_text.append(line.strip().lower())
    return " ".join(file_text)

file_text = load_text_file("wiki_food_en.txt")

# %% [markdown]
# <br>
# The following code uses the regular expression library to detect lexico-syntactic patterns in the file_text. The example below uses the regular expression "X is a Y". Fill in the blanks (...):

# %%
import re

def find_matches(file_text, regexp_string):
    #Compile a regular expression 
    regexp = re.compile(regexp_string)
    
    #Find all matches with the given regular expression
    matches = re.findall(regexp, file_text)
    
    return matches

isa_matches = find_matches(file_text, "[a-z]+ is a [a-z]+")

# %%
isa_matches
# Out:
# ['word is a compound',
#  'ajiaco is a popular',
#  'ajiaco is a hearty',
#  'ajiaco is a quite',
#  'bana is a small',
#  'hull is a reticulated',
#  'but is a popular',
#  'almond is a nutritionally',
#  'serving is a rich',
#  'oil is a rich',
#  'and is a glyceryl',
#  'hull is a reticulated',
#  'but is a popular',
#  'almond is a nutritionally',
#  'serving is a rich',
#  'oil is a rich',
#  'and is a glyceryl',
#  'it is a popular',
#  'and is a popular',
#  'it is a popular',
#  'it is a common',
#  'starter is a substitute',
#  'it is a simple',
#  'it is a coarse',
#  'it is a plump',
#  'cake is a white',
#  'foam is a type',
#  'that is a bright',
#  'protein is a soy',
#  'starch is a tenderizing',
#  'cake is a type',
#  'anise is a food',
#  'it is a key',
#  'which is a cool',
#  'which is a direct',
#  'butter is a family',
#  'syrup is a minority',
#  'butter is a product',
#  'it is a critical',
#  'refrigeration is a way',
#  'it is a method',
#  'there is a widespread',
#  'canning is a process',
#  'sauce is a lot',
#  'butter is a much',
#  'sauce is a homemade',
#  'apricot is a small',
#  'there is a considerable',
#  'page is a candidate',
#  'it is a major',
#  'head is a cluster',
#  'sucrose is a complex',
#  'there is a correlation',
#  'it is a good',
#  'season is a highlight',
#  'soil is a large',
#  'eggplant is a delicate',
#  'soup is a greek',
#  'lemon is a greek',
#  'it is a chance',
#  'it is a regular',
#  'and is a key',
#  'translation is a useful',
#  'churma is a complete',
#  'baati is a popular',
#  'it is a hybrid',
#  'it is a small',
#  'result is a dense',
#  'there is a belief',
#  'which is a type',
#  'there is a predominant',
#  'it is a thinner',
#  'company is a producer',
#  'powder is a double',
#  'bicarbonate is a white',
#  'it is a component',
#  'overdose is a serious',
#  'it is a very',
#  'there is a protective',
#  'it is a triploid',
#  'there is a risk',
#  'what is a plantain',
#  'twist is a bake',
#  'it is a ubiquitous',
#  'it is a caramelized',
#  'it is a lot',
#  'barley is a member',
#  'hairs is a characteristic',
#  'it is a midshort',
#  'it is a midwestern',
#  'it is a two',
#  'compana is a two',
#  'it is a white',
#  'and is a symbol',
#  'barley is a widely',
#  'and is a rich',
#  'it is a traditional',
#  'barley is a key',
#  'name is a personification',
#  'it is a bread',
#  'basbousa is a particularly',
#  'basil is a symbol',
#  'eugenol is a vanilloid',
#  'it is a traditional',
#  'it is a popular',
#  'which is a component',
#  'why is a cake',
#  'this is a dish',
#  'beef is a complete',
#  'there is a danger',
#  'states is a specification',
#  'broiling is a term',
#  'roasting is a way',
#  'beef is a thin',
#  'it is a form',
#  'beef is a source',
#  'industry is a global',
#  'industry is a global',
#  'which is a small',
#  'and is a key',
#  'hops is a preservative',
#  'industry is a global',
#  'brewpub is a type',
#  'yeast is a cool',
#  'colour is a pale',
#  'alcohol is a by',
#  'it is a low',
#  'which is a potent',
#  'beer is a thorny',
#  'it is a mixture',
#  'beet is a common',
#  'below is a list',
#  'it is a simple',
#  'it is a typical',
#  'berry is a simple',
#  'sauce is a traditional',
#  'drink is a form',
#  'distillation is a method',
#  'juice is a natural',
#  'industry is a global',
#  'brandy is a spirit',
#  'arnaise is a traditional',
#  'e is a variation',
#  'paloise is a version',
#  'word is a polish',
#  'translation is a useful',
#  'also is a commonly',
#  'bigoli is a term',
#  'biscuit is a small',
#  'pudding is a good',
#  'style is a specialty',
#  'that is a permitted',
#  'there is a tradition',
#  'region is a style',
#  'which is a piece',
#  'and is a rich',
#  'boli is a fictional',
#  'it is a variation',
#  'polony is a bright',
#  'it is a dried',
#  'it is a good',
#  'bologna is a long',
#  'bologna is a way',
#  'it is a very',
#  'borscht is a popular',
#  'them is a tart',
#  'which is a regional',
#  'borscht is a hot',
#  'it is a meal',
#  'borscht is a clear',
#  'it is a speciality',
#  'butifarra is a dish',
#  'it is a proper',
#  'institute is a regional',
#  'and is a popular',
#  'there is a common',
#  'translation is a useful',
#  'it is a separate',
#  'brandy is a common',
#  'brandy is a common',
#  'name is a variation',
#  'there is a vast',
#  'it is a very',
#  'sausage is a relatively',
#  'mixture is a closely',
#  'it is a common',
#  'nut is a large',
#  'itself is a large',
#  'nut is a hard',
#  'sourdough is a type',
#  'which is a grain',
#  'panko is a crumby',
#  'muesli is a breakfast',
#  'and is a common',
#  'pap is a porridge',
#  'it is a common',
#  'it is a central',
#  'which is a different',
#  'broccoli is a result',
#  'it is a cool',
#  'broccoli is a cool',
#  'bread is a form',
#  'bread is a type',
#  'sprouts is a common',
#  'it is a tubed',
#  'which is a wider',
#  'buckwheat is a rich',
#  'buckwheat is a good',
#  'tea is a relatively',
#  'salicylaldehyde is a characteristic',
#  'liquid is a base',
#  'translation is a useful',
#  'it is a multi',
#  'cabbage is a good',
#  'turn is a variant',
#  'tenderness is a valuable',
#  'cabbage is a staple',
#  'cake is a fruit',
#  'it is a two',
#  'it is a traditional',
#  'candy is a record',
#  'canola is a relatively',
#  'oil is a key',
#  'butterscotch is a hard',
#  'water is a necessary',
#  'soda is a good',
#  'coffee is a very',
#  'it is a naturally',
#  'cardoon is a stout',
#  's is a restaurant',
#  'cluster is a compound',
#  'there is a popular',
#  'which is a yellowing',
#  'apple is a light',
#  'tree is a kidney',
#  'fruit is a single',
#  'cashew is a known',
#  'oil is a dark',
#  'and is a byproduct',
#  'it is a raw',
#  'it is a disk',
#  'castile is a former',
#  'cauliflower is a delicious',
#  'cauliflower is a striking',
#  'celery is a staple',
#  'it is a staple',
#  'that is a staple',
#  'wings is a childhood',
#  'challah is a critical',
#  'salt is a requisite',
#  'there is a custom',
#  'challah is a form',
#  'it is a common',
#  'chapati is a form',
#  'there is a distinction',
#  'chard is a biennial',
#  'harvesting is a continuous',
#  'chard is a spring',
#  'there is a different',
#  'firmness is a common',
#  'mold is a significant',
#  'stringiness is a quality',
#  'cheese is a rich',
#  'there is a trend',
#  'cheese is a vital',
#  'cheese is a dairy',
#  'there is a variation',
#  'variation is a hot',
#  'dog is a little',
#  'coast is a fruit',
#  'it is a very',
#  'and is a fleshy',
#  'one is a hard',
#  'liquor is a traditional',
#  'this is a factor',
#  'tree is a reliable',
#  'it is a good',
#  'wood is a useful',
#  'which is a petroleum',
#  'sheeting is a technique',
#  'gum is a challenge',
#  'xylitol is a safe',
#  'acetate is a sticky',
#  'wax is a byproduct',
#  'there is a widely',
#  'extrusion is a very',
#  'stress is a likely',
#  'method is a promising',
#  'this is a broth',
#  'it is a traditional',
#  'soup is a clear',
#  'it is a very',
#  'soup is a traditional',
#  'britain is a clear',
#  'chicory is a native',
#  'it is a combination',
#  'cake is a cross',
#  'this is a traditional',
#  'it is a semi',
#  'wiener is a staple',
#  'it is a type',
#  'there is a family',
#  'this is a traditional',
#  'it is a hugely',
#  'mascot is a bear',
#  'it is a member',
#  'sum is a transliteration',
#  'sum is a green',
#  'it is a light',
#  'cake is a japanese',
#  'cake is a japanese',
#  'there is a popular',
#  'there is a popular',
#  'viewer is a dahi',
#  'chutney is a popular',
#  'technology is a private',
#  'translation is a useful',
#  'ciauscolo is a smoked',
#  'result is a very',
#  'it is a traditional',
#  'there is a pile',
#  'result is a liquid',
#  'applejack is a strong',
#  'doux is a sweet',
#  'brut is a strong',
#  'it is a traditional',
#  'result is a liquid',
#  'cider is a popular',
#  'it is a sparkling',
#  'it is a factory',
#  'type is a popular',
#  'singkut is a plant',
#  'cinnamon is a popular',
#  'cinnamon is a tree',
#  'name is a literal',
#  'and is a characteristic',
#  'there is a reference',
#  'there is a hard',
#  'there is a white',
#  'there is a clear',
#  'yield is a lack',
#  'milk is a popular',
#  'milk is a common',
#  'this is a dessert',
#  'milk is a rich',
#  'and is a common',
#  'coffee is a major',
#  'which is a family',
#  'there is a water',
#  'forecast is a rise',
#  'coffee is a rapidly',
#  'elsewhere is a short',
#  'there is a type',
#  'there is a type',
#  'it is a traditional',
#  'borscht is a popular',
#  'them is a tart',
#  'which is a regional',
#  'borscht is a hot',
#  'it is a meal',
#  'borscht is a clear',
#  'milk is a very',
#  'milk is a major',
#  'milk is a key',
#  'and is a national',
#  'michigan is a natural',
#  'variety is a fixture',
#  'it is a specialty',
#  'result is a smooth',
#  'concoction is a clear',
#  'filtration is a novel',
#  'this is a critical',
#  'vegetables is a way',
#  'this is a subdiscipline',
#  'it is a soft',
#  'seed is a spice',
#  'which is a gene',
#  'it is a member',
#  'each is a carpel',
#  'dimboa is a member',
#  'it is a direct',
#  'maize is a considerably',
#  'second is a soft',
#  'maize is a major',
#  'maize is a major',
#  'but is a definitive',
#  'handle is a clean',
#  'which is a corn',
#  'one is a green',
#  'this is a more',
#  'syrup is a combination',
#  'syrup is a warm',
#  'hfcs is a variant',
#  'drawing is a recreation',
#  'and is a dish',
#  'it is a common',
#  'this is a local',
#  'this is a popular',
#  'which is a yogurt',
#  'translation is a useful',
#  'it is a favorite',
#  'which is a type',
#  'it is a sweet',
#  'pinette is a mixture',
#  'it is a lot',
#  'this is a kind',
#  'there is a thin',
#  'there is a similar',
#  'cigarette is a diminutive',
#  'it is a staple',
#  'cucumber is a creeping',
#  'outbreak is a new',
#  'soup is a local',
#  'it is a more',
#  'cumin is a drought',
#  'cumin is a diploid',
#  'cumin is a cross',
#  'cupcakes is a collection',
#  'cupcakes is a collection',
#  'it is a plot',
#  'which is a mix',
#  'meat is a traditional',
#  'it is a raisin',
#  'contrasts is a rich',
#  'that is a traditional',
#  'it is a square',
#  'dill is a popular',
#  'dill is a soup',
#  'dill is a common',
#  'which is a meaty',
#  'it is a common',
#  'dill is a favorite',
#  'it is a poor',
#  'which is a disaccharide',
#  'sucrose is a simple',
#  'water is a necessary',
#  'result is a doughnut',
#  'and is a ball',
#  'there is a doughnut',
#  'doughnut is a traditional',
#  'doughnut is a popular',
#  'doughnut is a popular',
#  'this is a spot',
#  'there is a race',
#  'tonsure is a hairstyle',
#  'dosa is a typical',
#  'region is a matter',
#  'it is a thick',
#  'meal is a coarser',
#  'dough is a precursor',
#  'which is a disaccharide',
#  'sucrose is a simple',
#  'water is a necessary',
#  'result is a doughnut',
#  'and is a ball',
#  'there is a doughnut',
#  'doughnut is a traditional',
#  'doughnut is a popular',
#  'doughnut is a popular',
#  'this is a spot',
#  'there is a race',
#  'tonsure is a hairstyle',
#  'overwatering is a concern',
#  'which is a rich',
#  'bread is a part',
#  'bread is a nexus',
#  'there is a critical',
#  'there is a lack',
#  'term is a combination',
#  'eierpunsch is a german',
#  'pino is a seasoned',
#  'drinks is a common',
#  'there is a limitation',
#  'vodka is a popular',
#  'kahlua is a coffee',
#  'proper is a soup',
#  'there is a particular',
#  'there is a story',
#  'name is a reference',
#  'it is a simplified',
#  'it is a black',
#  'tre is a sun',
#  'there is a third',
#  'badge is a registered',
#  'falukorv is a cooked',
#  'it is a rich',
#  'there is a recipe',
#  'this is a plump',
#  'it is a warm',
#  'it is a popular',
#  'it is a popular',
#  'moth is a problem',
#  'it is a hardy',
#  'it is a highly',
#  'it is a rich',
#  'bulb is a crisp',
#  'fennel is a key',
#  'it is a popular',
#  'it is a seasonal',
#  'tzle is a city',
#  'financier is a term',
#  'sauce is a staple',
#  'there is a popular',
#  'there is a sweet',
#  'sauce is a staple',
#  'dish is a famous',
#  'obesity is a complex',
#  'this is a pancake',
#  'pathiri is a traditional',
#  'term is a misnomer',
#  'flour is a constituent',
#  'flour is a blend',
#  'flour is a special',
#  'flour is a flour',
#  'flour is a flour',
#  'flour is a flour',
#  'flour is a flour',
#  'peanuts is a high',
#  'cornstarch is a principal',
#  'example is a specialty',
#  'rosmarino is a popular',
#  'which is a popular',
#  'it is a sign',
#  'worldwide is a reflection',
#  'which is a cylindrical',
#  'retailing is a two',
#  'starvation is a significant',
#  'bacteria is a common',
#  'dish is a suitable',
#  'it is a way',
#  'it is a typical',
#  'rice is a common',
#  'it is a method',
#  'cake is a rich',
#  'it is a loaf',
#  'cake is a round',
#  'this is a fruit',
#  'and is a staple',
#  'it is a fact',
#  'it is a thick',
#  'halwa is a popular',
#  'halwa is a combination',
#  'it is a light',
#  'halwa is a popular',
#  'halwa is a light',
#  'galette is a large',
#  'variety is a hot',
#  'base is a deep',
#  'but is a combination',
#  'and is a broad',
#  'sauce is a very',
#  'which is a catch',
#  'it is a byproduct',
#  'which is a custom',
#  'garlic is a fundamental',
#  'garlic is a popular',
#  'salt is a common',
#  'ams is a volatile',
#  'it is a very',
#  'powder is a common',
#  'following is a typical',
#  'it is a meat',
#  'characters is a benevolent',
#  'and is a typical',
#  'it is a typical',
#  'it is a whole',
#  'genoise is a basic',
#  'it is a close',
#  'result is a sweeter',
#  'and is a distinctly',
#  'which is a softer',
#  'gin is a common',
#  'this is a juniper',
#  'and is a common',
#  'and is a type',
#  'ginger is a key',
#  'which is a mixture',
#  'ginger is a common',
#  'ginger is a popular',
#  'ginger is a minor',
#  'which is a descendant',
#  'cake is a flat',
#  'restaurants is a must',
#  'it is a rich',
#  'concord is a variety',
#  'grapefruit is a rich',
#  'there is a popular',
#  'grapefruit is a pummelo',
#  'gravy is a staple',
#  'used is a shallow',
#  'chimichurri is a popular',
#  'and is a common',
#  'e is a thin',
#  'bread is a type',
#  'pizza is a german',
#  'it is a traditional',
#  'translation is a useful',
#  'fruit is a key',
#  'guava is a popular',
#  'oil is a source',
#  'restaurants is a soup',
#  'gumbo is a veritable',
#  'gumbo is a heavily',
#  'it is a color',
#  'gumbo is a reinterpretation',
#  'gumbo is a central',
#  'it is a central',
#  'there is a lack',
#  'whisky is a proper',
#  'which is a long',
#  'hallulla is a flat',
#  'cake is a dense',
#  'harissa is a common',
#  'pudding is a traditional',
#  'hazelnuts is a plat',
#  'sweeper is a low',
#  'sweeper is a powerful',
#  'harvester is a slow',
#  'it is a supercooled',
#  'it is a mixture',
#  'intoxication is a result',
#  'honey is a symbol',
#  'this is a sign',
#  'flowers is a resulting',
#  'which is a cool',
#  'which is a direct',
#  'it is a root',
#  'horseradish is a common',
#  'cream is a mixture',
#  'table is a part',
#  'and is a traditional',
#  'soup is a common',
#  'it is a drink',
#  'chocolate is a very',
#  'it is a typical',
#  'reganmian is a popular',
#  'bon is a popular',
#  'sauce is a style',
#  'sauce is a thick',
#  'sauces is a relatively',
#  'and is a popular',
#  'hummus is a popular',
#  'hummus is a common',
#  'and is a good',
#  'hummus is a centuries',
#  'result is a smooth',
#  'following is a partial',
#  'that is a mixture',
#  'labler is a sweet',
#  'idli is a savoury',
#  'infusion is a very',
#  'frying is a common',
#  'noodle is a popular',
#  'it is a leading',
#  'and is a major',
#  'frying is a common',
#  'noodle is a popular',
#  'it is a leading',
#  'and is a major',
#  'drying is a recent',
#  'dog is a new',
#  'dish is a local',
#  'which is a dried',
#  'there is a long',
#  'cama is a species',
#  'sauce is a combination',
#  'it is a representative',
#  'juice is a popular',
#  'processing is a type',
#  'sugar is a poison',
#  'there is a variant',
#  'it is a traditional',
#  'kale is a good',
#  'kale is a source',
#  'it is a side',
#  'it is a thick',
#  'kasha is a dish',
#  'kasha is a popular',
#  'there is a local',
#  'ketchup is a sweet',
#  'manis is a sweet',
#  'that is a mixture',
#  'following is a list',
#  'ketchup is a source',
#  'ketchup is a non',
#  'it is a shear',
#  'water is a large',
#  'it is a long',
#  'it is a popular',
#  'throw is a coconut',
#  'there is a potential',
#  'there is a story',
#  'it is a generally',
#  'kiwi is a national',
#  'egg is a programme',
#  'strike is a threat',
#  'tajima is a strain',
#  'japan is a registered',
#  'and is a low',
#  'kohlrabi is a commonly',
#  'nut is a caffeine',
#  'it is a lowland',
#  'weeding is a must',
#  'kommissbrot is a dark',
#  'it is a local',
#  'it is a local',
#  'it is a local',
#  'it is a local',
#  'it is a distinctly',
#  'it is a round',
#  'amann is a speciality',
#  'it is a common',
#  'torte is a kuchen',
#  'it is a traditional',
#  'which is a commonly',
#  'and is a popular',
#  'it is a traditional',
#  'it is a traditional',
#  'kugel is a common',
#  'kulen is a shelf',
#  'kumquat is a fairly',
#  'kolyvo is a ukrainian',
#  'noodle is a more',
#  'it is a traditional',
#  'kyselo is a close',
#  'there is a soup',
#  'it is a variation',
#  'preparation is a little',
#  'kyselo is a very',
#  'there is a sweet',
#  'which is a combination',
#  'laksa is a sour',
#  'laksam is a popular',
#  'soup is a mixture',
#  'soup is a yellowish',
#  'soup is a mixture',
#  'which is a mixture',
#  'it is a specialty',
#  'it is a sliced',
#  'which is a type',
#  'ingredient is a paste',
#  'generally is a final',
#  'n is a loanword',
#  'also is a liquor',
#  'lard is a product',
#  'it is a narrower',
#  'what is a lasagnette',
#  'plant is a bundle',
#  'which is a cognate',
#  'which is a traditional',
#  'lettuce is a rich',
#  'type is a head',
#  'effect is a property',
#  'plant is a herbaceous',
#  'it is a small',
#  'it is a plural',
#  'it is a plural',
#  'it is a type',
#  'it is a thicker',
#  'bun is a small',
#  'bun is a popular',
#  'tree is a medium',
#  'longaniza is a very',
#  'longaniza is a popular',
#  'it is a large',
#  'flavour is a mixture',
#  'this is a cultivar',
#  'and is a popular',
#  'there is a risk',
#  'spices is a popular',
#  'meat is a traditional',
#  'it is a favorite',
#  'fruit is a very',
#  'it is a popular',
#  'this is a rather',
#  'food is a traditional',
#  'there is a constant',
#  'that is a staple',
#  'it is a baked',
#  'tart is a variation',
#  'thick is a thin',
#  'style is a form',
#  'mangosteen is a native',
#  'there is a legend',
#  'sandwich is a sandwich',
#  'manwich is a meal',
#  'it is a perennial',
#  'that is a genus',
#  'it is a sugar',
#  'albumen is a mixture',
#  'it is a disaccharide',
#  'sucrose is a main',
#  'passover is a commemoration',
#  'matzo is a favorite',
#  'this is a matter',
#  'there is a custom',
#  'there is a difference',
#  'and is a common',
#  'it is a rich',
#  'it is a stable',
#  'mayonnaise is a mixture',
#  'result is a water',
#  'it is a combination',
#  'it is a thermodynamically',
#  'butter is a water',
#  'spoilage is a big',
#  'vinegar is a proprietary',
#  'it is a specialty',
#  'mbeju is a staple',
#  'there is a poem',
#  'which is a species',
#  'mead is a popular',
#  'pyment is a melomel',
#  'term is a phonetic',
#  'there is a friday',
#  'pyment is a melomel',
#  'it is a very',
#  'infertility is a common',
#  'cases is a good',
#  'cholesterol is a lipid',
#  'there is a very',
#  'and is a breeding',
#  'it is a significant',
#  'meat is a typical',
#  'veal is a byproduct',
#  'melon is a kind',
#  'melon is a cooking',
#  'it is a popular',
#  'there is a second',
#  'what is a casaba',
#  'memela is a thick',
#  'memela is a toasted',
#  'sauce is a simple',
#  'sauce is a variation',
#  'pizza is a popular',
#  'there is a variety',
#  'fresh is a pizza',
#  'there is a facility',
#  'pizza is a free',
#  'which is a chick',
#  'and is a traditional',
#  'milk is a good',
#  'lactose is a disaccharide',
#  'there is a loss',
#  'intolerance is a condition',
#  'milk is a slightly',
#  'milk is a drink',
#  'there is a request',
#  'there is a lesson',
#  'it is a common',
#  'millet is a c',
#  'and is a rich',
#  'genovese is a variant',
#  'which is a fermented',
#  'such is a traditional',
#  'it is a very',
#  'mofletta is a thin',
#  'it is a protein',
#  'that is a staple',
#  'it is a defining',
#  'molasses is a common',
#  'it is a soft',
#  'asadero is a creamy',
#  'mortadella is a product',
#  'there is a local',
#  'it is a type',
#  'taghziah is a famous',
#  'it is a very',
#  'muffin is a type',
#  'photo is a sequence',
#  'result is a white',
#  'translation is a useful',
#  'it is a fashionable',
#  'and is a meal',
#  'which is a deformed',
#  'there is a similar',
#  'that is a typical',
#  'it is a creamy',
#  'it is a speciality',
#  'palmette is a palmette',
#  'it is a good',
#  'none is a significant',
#  'jam is a common',
#  'tarts is a recipe',
#  'tzle is a city',
#  'it is a clear',
#  'it is a popular',
#  'this is a tunstall',
#  'oatmeal is a prime',
#  'it is a plate',
#  'milk is a traditional',
#  'milk is a popular',
#  'oat is a prolamine',
#  'avenae is a pathogen',
#  'processing is a relatively',
#  'it is a vital',
#  'soba is a regional',
#  'monjayaki is a liquid',
#  'soup is a mix',
#  'which is a non',
#  'it is a type',
#  'loaf is a loaf',
#  'it is a common',
#  'loaf is a sausage',
#  'italy is a net',
#  'oil is a usual',
#  'oil is a product',
#  'acidity is a measure',
#  'oil is a source',
#  'which is a species',
#  'vegetable is a common',
#  'leaves is a very',
#  'leaf is a flattened',
#  'powder is a seasoning',
#  'shanking is a condition',
#  'rot is a fungal',
#  'onion is a prolific',
#  'onion is a hybrid',
#  'it is a common',
#  'powder is a commercially',
#  'it is a perennial',
#  'it is a highly',
#  'corn is a grain',
#  'context is a legacy',
#  'which is a popular',
#  'result is a rich',
#  'soup is a popular',
#  'sauce is a staple',
#  'it is a hard',
#  'it is a common',
#  'it is a common',
#  'it is a form',
#  'achappam is a deep',
#  'it is a signature',
#  'kuzhalappam is a typical',
#  'which is a fried',
#  'and is a signature',
#  'surface is a bit',
#  'it is a popular',
#  'it is a type',
#  'it is a sweetened',
#  'muerto is a simple',
#  'it is a cake',
#  'pe is a thin',
#  'and is a national',
#  'and is a staple',
#  'there is a variety',
#  'spekdik is a pancake',
#  'it is a lot',
#  'crust is a golden',
#  'papaya is a large',
#  'fruit is a type',
#  'and is a significant',
#  'hungary is a major',
#  'parsley is a bright',
#  'which is a mixed',
#  'parsley is a key',
#  'parsley is a source',
#  'parsley is a bright',
#  'which is a mixed',
#  'parsley is a key',
#  'parsley is a source',
#  'parsnip is a biennial',
#  'derived is a plant',
#  'canker is a serious',
#  'condition is a type',
#  'syrup is a popular',
#  'there is a general',
#  'there is a delightful',
#  'there is a legend',
#  'it is a healthy',
#  'there is a general',
#  'there is a delightful',
#  'there is a legend',
#  'it is a healthy',
#  'there is a very',
#  'pastry is a simple',
#  'pastry is a very',
#  'phyllo is a paper',
#  'result is a hot',
#  'and is a very',
#  'it is a main',
#  'it is a cool',
#  'pea is a most',
#  'there is a significant',
#  'soup is a common',
#  'it is a thick',
#  'it is a popular',
#  'germain is a thick',
#  'palmette is a palmette',
#  'it is a good',
#  'none is a significant',
#  'which is a hybrid',
#  'it is a medium',
#  'tree is a large',
#  'what is a praline',
#  'penne is a popular',
#  'penne is a versatile',
#  'this is a sound',
#  'there is a third',
#  ...]

# %% [markdown]
# <br>
#  ###  Question 1.b
#
# Run the above code for relations extraction with the following lexico-syntactic patterns:
#
# <ol>
#   <li>X such as Y</li>
#   <li>such X as Y</li>
# <li>X and other Y</li>
# </ol>
#
# Manually inspect the results and compute the accuracies of first 20 matches for each lexico-syntactic pattern. What do you observe? Is there any important difference between patterns no. 1,2 and 3?

# %%
suchas_matches = find_matches(file_text, "[a-z]+ such as [a-z]+")
for i,j in enumerate(suchas_matches[:20]):
    print(i+1,")",j)
# Out:
# 1 ) pig such as the
# 2 ) beverages such as cocktails
# 3 ) emulsifiers such as egg
# 4 ) varieties such as allioli
# 5 ) pests such as the
# 6 ) ceremonies such as weddings
# 7 ) pests such as navel
# 8 ) versions such as the
# 9 ) pests such as the
# 10 ) ceremonies such as weddings
# 11 ) pests such as navel
# 12 ) versions such as the
# 13 ) illnesses such as infections
# 14 ) pans such as a
# 15 ) manufacturing such as acetic
# 16 ) aid such as modified
# 17 ) session such as of
# 18 ) plants such as pear
# 19 ) foods such as apple
# 20 ) cheeses such as cheddar

# %%
such_matches = find_matches(file_text, "such [a-z]+ as [a-z]+")
for i,j in enumerate(such_matches[:20]):
    print(i+1,")",j)
# Out:
# 1 ) such serves as an
# 2 ) such flavors as chocolate
# 3 ) such factors as territorial
# 4 ) such countries as germany
# 5 ) such foods as pizza
# 6 ) such words as the
# 7 ) such factors as territorial
# 8 ) such companies as arienti
# 9 ) such ingredients as water
# 10 ) such ingredients as water
# 11 ) such places as thailand
# 12 ) such places as thailand
# 13 ) such parameters as the
# 14 ) such species as the
# 15 ) such nougat as the
# 16 ) such items as sliced
# 17 ) such species as the
# 18 ) such conditions as abscesses
# 19 ) such plants as the
# 20 ) such items as dry

# %%
other_matches = find_matches(file_text, "[a-z]+ and other [a-z]+")
for i,j in enumerate(other_matches[:20]):
    print(i+1,")",j)
# Out:
# 1 ) france and other countries
# 2 ) figs and other recipes
# 3 ) azerbaijan and other central
# 4 ) olives and other tree
# 5 ) azerbaijan and other central
# 6 ) olives and other tree
# 7 ) rye and other flours
# 8 ) france and other european
# 9 ) sauces and other sauces
# 10 ) mixes and other gluten
# 11 ) petals and other flower
# 12 ) petals and other flower
# 13 ) tariff and other supports
# 14 ) wars and other fairtrade
# 15 ) wine and other ingredients
# 16 ) date and other agronomic
# 17 ) soups and other foods
# 18 ) patties and other bulk
# 19 ) spices and other substances
# 20 ) sugars and other components

# %% [markdown]
# ## Question 2 - Graph Construction
#
# As you noticed in the previous step, the output of lexico-syntactic patterns-based relations extraction contains significant noise. The task of noise removal is fairly involved and beyond the scope of this exercise. For further reading, we recommend this paper, which demonstrates a state-of-the-art effort for IsA relations extraction (<a href="http://webdatacommons.org/isadb/lrec2016.pdf">A Large Database of Hypernymy Relations Extracted from the Web</a>).
#
# In this part of the exercise, we assume that IsA relations extracted using a state-of-the-art approach are already available. Given these relations, the aim of this step is to construct an initial potentially-noisy hypernym graph.
#
# ###  Question 2.a
#
#
# Load the IsA relations of the food domain from the given file "food_isa_relations.txt" using the following code:

# %%
rels = []
with open("food_isa_relations.txt") as fp:
    for line in fp.readlines():
        toks = line.strip().split('\t')
        rels.append((toks[0],toks[1],float(toks[2])))

# %% [markdown]
# In python, graphs are better handled as a default 2-level dictionary. For example, the edge (<i>apple</i>,<i>fruit</i>, freq) is represented as a two-level map:
#
# map['apple']['fruit'] = freq
#
# The following code converts the IsA relations loaded from the file into a 2-level dictionary. Fill in the blanks:

# %%
from collections import defaultdict

noisy_relations = defaultdict(dict)
for hypo, hyper, freq in rels:
    noisy_relations[hypo][hyper] = freq

# %% [markdown]
# <br>
#
# ###  Question 2.b
#
# The next step of taxonomy induction involves removing and filtering out noisy IsA relations. In a real scenario, this usually involves a wide variety of steps. However, in this exercise, we will implement only one step. In this step, we will sort all the hypernyms for each hyponym, and only retain top-5 hypernyms for each hyponym.
#
# First, print the hypernyms of 'apple':

# %%
noisy_relations['apple']
# Out:
# {'fruit': 1.0,
#  'company': 0.547120747653,
#  'apple': 0.41334243636,
#  'orange': 0.155466692675,
#  'food': 0.147812587177,
#  'vegetable': 0.132148274312,
#  'tech company': 0.120745147762,
#  'fruit tree': 0.115782511138,
#  'tree': 0.110838111316,
#  'crop': 0.0988772876235,
#  'brand': 0.0915626602388,
#  'hardware company': 0.0897298351702,
#  'flavour': 0.0858994706649,
#  'manufacturer': 0.079702775123,
#  'rival': 0.0788062030625,
#  'technology company': 0.0755438963724,
#  'company in the world': 0.0747098410221,
#  'tag': 0.0736281177128,
#  'product': 0.0697003665663,
#  'ingredient': 0.068957229831}

# %% [markdown]
# <br>
# Fill in the blanks in the following code:

# %%
for hypo in noisy_relations.keys():
    sorted_hypernyms = sorted(noisy_relations[hypo].items(), key = lambda x: -x[1])
    noisy_relations[hypo] = {k:v for k,v in sorted_hypernyms[:5]}
    
# Printed filtered noisy relations.
noisy_relations['apple']
# Out:
# {'fruit': 1.0,
#  'company': 0.547120747653,
#  'apple': 0.41334243636,
#  'orange': 0.155466692675,
#  'food': 0.147812587177}

# %% [markdown]
# ###  Question 2.c
#
# In the next step, we would first convert the set of filtered IsA relations into a graph. First install the library networkx and matplotlib:
#
#    $ pip install networkx<br>
#
#    $ pip install matplotlib
#
#
#
# Further, use the following code:

# %%
import networkx as nx
import matplotlib.pyplot as plt

G=nx.DiGraph()

for hypo in noisy_relations.keys():
    for hyper in noisy_relations[hypo].keys():
        G.add_edge(hypo, hyper)

# %% [markdown]
# <br>
# Print all the paths between the following terms (Hint: use the networkx function all_simple_paths):
#
# 1. 'apple' and 'food'
# 2. 'fusilli' and 'food'
# 3.  'okra' and 'food'
#
# Do you notice any relationship between the length of the path and its accuracy?

# %%
for p in nx.all_simple_paths(G, source='apple', target='food'):
    print (p)
# Out:
# ['apple', 'fruit', 'food']
# ['apple', 'fruit', 'ingredient', 'food']
# ['apple', 'orange', 'fruit', 'food']
# ['apple', 'orange', 'fruit', 'ingredient', 'food']
# ['apple', 'food']

# %%
for p in nx.all_simple_paths(G, source='fusilli', target='food'):
    print (p)
# Out:
# ['fusilli', 'pasta', 'food']
# ['fusilli', 'pasta', 'dish', 'food']
# ['fusilli', 'pasta', 'ingredient', 'food']

# %%
for p in nx.all_simple_paths(G, source='okra', target='food'):
    print (p)
# Out:
# ['okra', 'vegetable', 'food']
# ['okra', 'vegetable', 'ingredient', 'food']

# %% [markdown]
# ###  Question 2.d
#
# In this step, we will now build a taxonomy. We will undertake the following steps:
#
# <ol>
#   <li> Let the vocabulary be {'apple', 'mango', 'peach', 'orange', 'banana'}.</li>
# <li> Let the root of the taxonomy be 'food'.</li>
# <li> Find all simple paths between terms in the vocabulary and the root. </li>
# <li> Retain all simple paths of length $l$.
# <li> Construct a graph by aggregatiing all the edges in the retained paths. </li>
#
# The below code implements the above steps. Fill in the blanks:

# %%
# %matplotlib inline
def select_paths(vocab, root, l):
    retained_paths = []
    for term in vocab:
        for path in nx.all_simple_paths(G, source=term, target=root):
            if len(path)==l:
                retained_paths.append(path)
    return retained_paths


def aggregate_paths(paths):
    agg_graph = defaultdict(dict)
    
    for path in paths:
        for i,term in enumerate(path[0:len(path) -1]):
            agg_graph[term][path[i+1]] = 1
            
    return agg_graph


V = ['apple', 'mango', 'peach', 'orange', 'banana']
root = 'food'

graph = aggregate_paths(select_paths(V, root, 3))
 

# Plot the graph
Gt = nx.DiGraph()
for k in graph.keys():
    for k1 in graph[k].keys():
        Gt.add_edge(k,k1)
nx.draw(Gt, with_labels=True)            
plt.show()

# %% [markdown]
# ###  Question 2.e
#
# Plot the aggregated graph using the previous steps but with different path lengths (For example, 2 or 4). What do you notice?

# %%
graph = aggregate_paths(select_paths(V, root, 2))
 

# Plot the graph
Gt = nx.DiGraph()
for k in graph.keys():
    for k1 in graph[k].keys():
        Gt.add_edge(k,k1)
nx.draw(Gt, with_labels=True)            
plt.show()

# %%
graph = aggregate_paths(select_paths(V, root, 4))
 

# Plot the graph
Gt = nx.DiGraph()
for k in graph.keys():
    for k1 in graph[k].keys():
        Gt.add_edge(k,k1)
nx.draw(Gt, with_labels=True)            
plt.show()

# %% [markdown]
# ###  Question 2.f
#
# Repeat steps from 2.b to 2.e but without filtering the noisy relations in step 2.b. What do you observe?
